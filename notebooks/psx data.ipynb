# %%
import sys
print(sys.version)
print(sys.executable)

# %%
conda create -n psx python=3.13 -y #get value from sys.version for python
conda activate psx
pip install psxdata pandas openpyxl jupyter

# %%
#%pip install  psxdata pandas openpyxl # if you donot want to install in an enviroment but whrere python in install

# %%
import os
os.chdir(r"C:\Users\ZA Technologies\Downloads")

# %%
import psxdata

# One company
df = psxdata.stocks(
    "OGDC",
    start="2021-09-23",
    end="2026-09-23"
)
# Out:
# Dates are not in chronological order

# %%
print(df)
# Out:
#            date   open    high     low   close   volume  is_anomaly
# 0    2026-09-23  318.9  320.30  318.63  319.53  1712061       False
# 1    2026-09-22  317.8  319.10  316.00  318.41  1143864       False
# 2    2026-09-21  319.0  319.90  317.00  317.49  1591013       False
# 3    2026-09-18  317.0  320.50  315.91  318.06  2977934       False
# 4    2026-09-17  315.7  317.50  312.20  316.20  2246109       False
# ...         ...    ...     ...     ...     ...      ...         ...
# 1235 2021-09-29   83.0   83.50   81.20   81.59  6406389       False
# 1236 2021-09-28   84.4   84.50   81.25   83.39  7349133       False
# 1237 2021-09-27   84.9   85.50   83.90   84.62  2957017       False
# 1238 2021-09-24   84.0   84.60   82.95   84.24  2210113       False
# 1239 2021-09-23   85.3   85.95   81.00   83.43  3059990       False
#
# [1240 rows x 7 columns]

# %%
df.to_csv("OGDC_5years.csv")

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# C:\Users\ZA Technologies\AppData\Local\Programs\Python\Python313\python.exe

# %%
pwd()
# Out:
# 'C:\\Windows\\system32'

# %%
print(os.getcwd())
# Out:
# C:\Users\ZA Technologies\Downloads

# %%
import psxdata
import pandas as pd

# Stocks you want
tickers = ["OGDC", "PPL", "HBL", "MCB", "UBL", "LUCK", "PSO"]

# Get current KSE-100 constituents automatically
#tickers = psxdata.tickers(index="KSE100")

print("Number of stocks:", len(tickers))
print(tickers)

start_date = "2021-09-23"
end_date   = "2026-09-23"

all_data = []

for ticker in tickers:

    try:
        print(f"Downloading {ticker}...")

        df = psxdata.stocks(
            ticker,
            start=start_date,
            end=end_date
        )

        if not df.empty:
            df["symbol"] = ticker
            all_data.append(df)

    except Exception as e:
        print(f"Problem with {ticker}: {e}")

# Combine all stocks
data = pd.concat(all_data, ignore_index=True)

# Arrange columns
data = data[
    ["date", "symbol", "open", "high",
     "low", "close", "volume", "is_anomaly"]
]

# Sort panel
data = data.sort_values(["symbol", "date"])

# Save CSV
data.to_csv(
    "KSE100_daily_5years.csv",
    index=False
)

# Save Excel
data.to_excel(
    "KSE100_daily_5years.xlsx",
    index=False
)

print("\nFinished.")
print("Observations:", len(data))
print("Stocks:", data["symbol"].nunique())

print(data.head())
# Out:
# Number of stocks: 7
# ['OGDC', 'PPL', 'HBL', 'MCB', 'UBL', 'LUCK', 'PSO']
# Downloading OGDC...
# Downloading PPL...
# Downloading HBL...
# Downloading MCB...
# Downloading UBL...
# Downloading LUCK...
# Downloading PSO...
#
# Finished.
# Observations: 8675
# Stocks: 7
#            date symbol    open    high     low   close   volume  is_anomaly
# 3719 2021-09-23    HBL  115.50  116.40  114.00  115.46   818807       False
# 3718 2021-09-24    HBL  115.99  115.99  113.51  114.89   143084       False
# 3717 2021-09-27    HBL  115.00  115.00  111.00  111.99  5459595       False
# 3716 2021-09-28    HBL  112.00  113.70  111.52  112.54  7044937       False
# 3715 2021-09-29    HBL  113.90  113.90  110.41  110.91  1347349       False
