# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ZA Technologies\Downloads\Data-Analytics\notebooks

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: C:\Users\ZA Technologies\Downloads\Data-Analytics

# %%
from src.psx_download import download_stocks

print("PSX download function imported successfully.")
# Out:
# PSX download function imported successfully.

# %%
tickers = [
    "OGDC",
    "PPL",
    "HBL",
    "MCB",
    "UBL",
    "LUCK",
    "PSO"
]

# %%
start_date = "2021-09-23"
end_date = "2026-09-23"

# %%
data = download_stocks(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date
)
# Out:
# Downloading OGDC...
# Downloading PPL...
# Downloading HBL...
# Downloading MCB...
# Downloading UBL...
# Downloading LUCK...
# Downloading PSO...

# %%
data.head()
# Out:
#         date    open    high     low   close   volume  is_anomaly symbol
# 0 2021-09-23  115.50  116.40  114.00  115.46   818807       False    HBL
# 1 2021-09-24  115.99  115.99  113.51  114.89   143084       False    HBL
# 2 2021-09-27  115.00  115.00  111.00  111.99  5459595       False    HBL
# 3 2021-09-28  112.00  113.70  111.52  112.54  7044937       False    HBL
# 4 2021-09-29  113.90  113.90  110.41  110.91  1347349       False    HBL

# %%
print("Rows:", len(data))
print("Stocks:", data["symbol"].nunique())
print("Columns:", data.columns.tolist())
# Out:
# Rows: 8675
# Stocks: 7
# Columns: ['date', 'open', 'high', 'low', 'close', 'volume', 'is_anomaly', 'symbol']

# %%
data.shape
# Out:
# (8675, 8)

# %%
data["symbol"].value_counts()
# Out:
# symbol
# HBL     1240
# MCB     1240
# OGDC    1240
# PPL     1240
# PSO     1240
# UBL     1240
# LUCK    1235
# Name: count, dtype: int64

# %%
from pathlib import Path

# Define folders relative to the project root
RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DATA_DIR = PROJECT_ROOT / "data" / "processed"
RESULTS_DIR = PROJECT_ROOT / "results"

# Create them if they do not already exist
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

print("Raw data folder:", RAW_DATA_DIR)
# Out:
# Raw data folder: C:\Users\ZA Technologies\Downloads\Data-Analytics\data\raw

# %%
file_path = RAW_DATA_DIR / "psx_daily_2021_2026.csv"

data.to_csv(
    file_path,
    index=False
)

print("Saved successfully:")
print(file_path)
# Out:
# Saved successfully:
# C:\Users\ZA Technologies\Downloads\Data-Analytics\data\raw\psx_daily_2021_2026.csv

# %%
print(file_path.exists())
# Out:
# True

# %%
print(f"File size: {file_path.stat().st_size / 1024:.1f} KB")
# Out:
# File size: 470.6 KB
