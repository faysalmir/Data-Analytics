# %%
import pandas as pd

from src.psx_download import download_stocks

# %%
tickers = [
    "OGDC",
    "PPL",
    "HBL",
    "MCB",
    "UBL",
    "LUCK",
    "PSO"
]

# %%
start_date = "2021-09-23"
end_date = "2026-09-23"

# %%
data = download_stocks(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date
)

# %%
data.head()

# %%
data.shape

# %%
data["symbol"].value_counts()

# %%
data.to_csv(
    "data/raw/psx_daily_2021_2026.csv",
    index=False
)
